# %%
def minimum(arr):
    minimum = maximum = x[0]
    for i in x[1:]:
        if i < minimum:
            minimum = i
        else:
            if i > maximum: maximum = i
    return (minimum,maximum)
print(minmax1([4,6,2,1,9,63,-134,566]))
print(minmax1([-52,56,30,29,-54,0,-110]))
print(minmax1([42,54,65,87,0]))
print(minmax1([5]))
# Out:
# (-134, 566)
# (-110, 56)
# (0, 87)
# (5, 5)
