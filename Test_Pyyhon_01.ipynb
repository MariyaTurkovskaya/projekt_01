# %% [markdown]
# # python. основы. типы данных

# %% [markdown]
# ## типы данных
# * int - целое число
# * float - вещественное число
#
# TODO - математика в python
# TODO - индексация строк
# TODO - списки и кортежи. отличие
# TODO - переменные
#
# ## функция
# * print ()
# * type ()
# * round ()

# %%
# сложение
2 + 2
# Out:
# 4

# %%
# вычитание
2 - 2
# Out:
# 0

# %%
# умножение
2 * 2
# Out:
# 4

# %%
2 * 2
# Out:
# 4

# %%
# деление
# type (2 / 2)
# узнать тип данных с помощью функции type ()
print(type(2 / 2))

# обычное деление -> результат float
print(2 / 2)
2 // 2

# деление нацело -> результат int
print(2 // 2)

# остаток от деления -> результат int
print(2 % 2)
# Out:
# <class 'float'>
# 1.0
# 1
# 0

# %%
30.0 // 3
41 / 3
#type(30.0)
# Out:
# 13.666666666666666

# %%
# сравнения
# > < == <= >= !=
2 > 1
0.1 + 0.2 == 0.3
print(0.1 + 0.2)
# Out:
# 0.30000000000000004

# %%
# округление
# round(12.46, 1)
# Out:
# 12.5
